# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (4.38.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.6.3)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from selenium) (2026.1.4)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.1)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# This automatically downloads the correct driver and handles the path for you
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

driver.get("https://www.google.com")

# %%
# Get the page’s contents

page_url = "https://en.wikipedia.org/wiki/Key_events_of_the_20th_century"
driver.get(page_url)

# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\anita boadu\anaconda3\envs\20th_century\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# This automatically downloads the correct driver and handles the path for you
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

driver.get("https://www.google.com")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# This automatically manages the driver version for you
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %%
# Define the URL
url = "https://en.wikipedia.org/wiki/Key_events_of_the_20th_century"

# Use Selenium to load the page
driver.get(url)

# Grab the page source to parse with BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Extract all text
scraped_text = soup.get_text()
